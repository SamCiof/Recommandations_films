# %% [markdown]
# ## Participants
#
# * Samantha
# * Rachelle
# * Andrew
#
#
# ## Résumé des observations
#
# Ce jeu de données comprend 4 colonnes et 8 258 774 lignes

# %% [markdown]
# # <div style='color:white;background: #005792;text-align: center;padding: 15px 0'>Recommandations - Visualisation de la source de données Title Episode</div>

# %% [markdown]
# ### Installation des librairies

# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# !pip install plotly-express
# !pip install plotly

# %% [markdown]
# ### Importation des librairies

# %%
import os
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

import re

# %% [markdown]
# ### Chargement des fichiers

# %%
source_dir= '/home/dstrec/dstrec/00_data_source/imdb_datasets'
name_file= 'title.episode.tsv'
file_path= f"{source_dir}/{name_file}"

df= pd.read_csv(file_path, sep='\t', na_values='\\N', low_memory=False)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8258774 entries, 0 to 8258773
# Data columns (total 4 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   tconst         object
#  1   parentTconst   object
#  2   seasonNumber   float64
#  3   episodeNumber  float64
# dtypes: float64(2), object(2)
# memory usage: 252.0+ MB

# %% [markdown]
# ### Visualisation de la part de non renseigné de chaque variable du fichier

# %%
#Visualisation de la part de non renseigné de chaque variable du fichier
########################################################################""
for i in df.columns.values:
    print("DataVisualisation de la variable ",i)
    print("Cette variable a ",len(df[i].unique())," valeurs distintes")    
    if df[i].isna().sum()>0:
       res= df[i].isnull().value_counts(normalize = "true")
       plt.figure(figsize = (4, 4))
       plt.pie(res, labels = ['Part des renseignés', 'Part des non renseignés'], autopct='%1.1f%%')
       plt.title("Visualisation de la part des valeurs null de la variable ")
       plt.show()
    else:
        print("Cette variable ne contient pas de données non renseignées","\n")
# Out:
# DataVisualisation de la variable  tconst
# Cette variable a  8258774  valeurs distintes
# Cette variable ne contient pas de données non renseignées
#
# DataVisualisation de la variable  parentTconst
# Cette variable a  204745  valeurs distintes
# Cette variable ne contient pas de données non renseignées
#
# DataVisualisation de la variable  seasonNumber
# Cette variable a  308  valeurs distintes
# DataVisualisation de la variable  episodeNumber
# Cette variable a  15785  valeurs distintes

# %% [markdown]
# ### Autres visualisations

# %%
#BoxPlot nb de saisons des series
##################################
sns.boxplot(x =df['seasonNumber'])
plt.xlabel('BoxPlot nb de saisons des series')
#plt.xlabel('Nb (en million)')
#plt.ticklabel_format(style='plain', axis='x')
plt.show()

# %%
df['NewseasonNumber'] = df.apply(lambda x : "Sup_20" if x['seasonNumber']>20 else x['seasonNumber'],  axis=1)

ax = sns.barplot(y=df['NewseasonNumber'].value_counts(normalize=True).values*100,
            x=df['NewseasonNumber'].value_counts(normalize=True).index)
ax.tick_params(axis='x', rotation=90)
plt.title("Répartition du nombre de saisons des series")
plt.show()
